# %% [markdown]
# <a href="https://colab.research.google.com/github/Pandatoey/LAB229351/blob/main/%E0%B8%AA%E0%B8%B3%E0%B9%80%E0%B8%99%E0%B8%B2%E0%B8%82%E0%B8%AD%E0%B8%87_Lab04_Naive_Bayes_Grid_and_Random_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Statistical Learning for Data Science 2 (229352)
# #### Instructor: Donlapark Ponnoprat
#
# #### [Course website](https://donlapark.pages.dev/229352/)
#
# ## Lab #4

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

from scipy.stats import uniform

# %%
train = fetch_20newsgroups(subset='train')
test = fetch_20newsgroups(subset='test')

Xtrain = train.data[:3000]
ytrain = train.target[:3000]
Xtest = test.data[:500]
ytest = test.target[:500]

print("X:", len(Xtest))
print("y:", len(ytest))
# Out:
# X: 500
# y: 500

# %% [markdown]
# ### Naive Bayes [(Documentation)](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html)

# %%
pipeline = Pipeline([('tfidf', TfidfVectorizer(stop_words = 'english')),
                     ('nb', MultinomialNB())]) # Laplace smoothing parameter default = 1.0
pipeline.fit(Xtrain, ytrain)

ypred = pipeline.predict(Xtest)
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.38      0.48        21
#            1       0.79      0.52      0.63        21
#            2       0.58      0.69      0.63        26
#            3       0.74      0.68      0.71        34
#            4       0.72      0.85      0.78        34
#            5       0.88      0.81      0.84        26
#            6       1.00      0.73      0.84        22
#            7       0.70      1.00      0.82        28
#            8       0.90      0.82      0.86        33
#            9       0.88      0.84      0.86        25
#           10       0.82      1.00      0.90        27
#           11       0.79      0.95      0.86        20
#           12       0.59      0.54      0.57        24
#           13       0.75      0.78      0.77        23
#           14       0.87      0.71      0.78        28
#           15       0.53      0.90      0.67        29
#           16       0.50      0.95      0.66        21
#           17       0.94      0.83      0.88        18
#           18       0.86      0.23      0.36        26
#           19       0.00      0.00      0.00        14
#
#     accuracy                           0.73       500
#    macro avg       0.72      0.71      0.70       500
# weighted avg       0.74      0.73      0.71       500
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Random Search Cross-Validation [(Documentation)](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
#
# ### Uniform distribution in `Scipy` [(Documentation)](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.uniform.html)

# %%
# Random search Cross-Validation

parameters = {'nb__alpha': uniform(loc =0, scale=10)}
clf = RandomizedSearchCV(pipeline, parameters, n_iter=7)

clf.fit(Xtrain, ytrain)
# Out:
# RandomizedSearchCV(estimator=Pipeline(steps=[('tfidf',
#                                               TfidfVectorizer(stop_words='english')),
#                                              ('nb', MultinomialNB())]),
#                    n_iter=7,
#                    param_distributions={'nb__alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7e9afb699c70>})

# %% [markdown]
# #### Exercise
#
# 1. For the Naive Bayes model, use grid search 5-fold cross-validation across different values of `alpha` to find the best model.
#
# 2. For the best value of `alpha`, compute the `f1_macro` score on the test set.
# * What value of `alpha` did you obtain?
# * What is the model's `f1_macro` score?
#
# 3. Repeat Exercise 1 and 2 for **random search** 5-fold cross validation across different values of `alpha`. Compute the `f1_macro` score on the test set.
# * What value of `alpha` did you obtain?
# * Did you get a better `f1_macro` score compared to grid search in Exercise 2?

# %%
ypred = clf.predict(Xtest)
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.43      0.53        21
#            1       0.72      0.62      0.67        21
#            2       0.62      0.69      0.65        26
#            3       0.73      0.71      0.72        34
#            4       0.78      0.85      0.82        34
#            5       0.91      0.77      0.83        26
#            6       1.00      0.73      0.84        22
#            7       0.72      1.00      0.84        28
#            8       0.90      0.82      0.86        33
#            9       0.91      0.84      0.88        25
#           10       0.82      1.00      0.90        27
#           11       0.76      0.95      0.84        20
#           12       0.61      0.58      0.60        24
#           13       0.82      0.78      0.80        23
#           14       0.88      0.82      0.85        28
#           15       0.54      0.90      0.68        29
#           16       0.51      0.95      0.67        21
#           17       0.94      0.83      0.88        18
#           18       0.88      0.27      0.41        26
#           19       0.00      0.00      0.00        14
#
#     accuracy                           0.75       500
#    macro avg       0.74      0.73      0.71       500
# weighted avg       0.75      0.75      0.73       500
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Define model
pipeline_ex = Pipeline([('tfidf', TfidfVectorizer(stop_words = 'english')),
                     ('nb', MultinomialNB())]) # Laplace smoothing parameter default = 1.0
pipeline_ex.fit(Xtrain, ytrain)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(stop_words='english')),
#                 ('nb', MultinomialNB())])

# %%
# Grid search 5-fold cross validation
import numpy as np
# Define parameters
param = {'nb__alpha': np.logspace(-3, 1, 20)}

# Define Grid-search CV
gridcv = GridSearchCV(pipeline_ex, param,
                      scoring='f1_macro', cv=5) # Cross validation = 5
gridcv.fit(Xtrain, ytrain)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tfidf',
#                                         TfidfVectorizer(stop_words='english')),
#                                        ('nb', MultinomialNB())]),
#              param_grid={'nb__alpha': array([1.00000000e-03, 1.62377674e-03, 2.63665090e-03, 4.28133240e-03,
#        6.95192796e-03, 1.12883789e-02, 1.83298071e-02, 2.97635144e-02,
#        4.83293024e-02, 7.84759970e-02, 1.27427499e-01, 2.06913808e-01,
#        3.35981829e-01, 5.45559478e-01, 8.85866790e-01, 1.43844989e+00,
#        2.33572147e+00, 3.79269019e+00, 6.15848211e+00, 1.00000000e+01])},
#              scoring='f1_macro')

# %%
# Print
ypred = gridcv.predict(Xtest)
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.67        21
#            1       0.52      0.52      0.52        21
#            2       0.62      0.58      0.60        26
#            3       0.68      0.68      0.68        34
#            4       0.84      0.76      0.80        34
#            5       0.84      0.62      0.71        26
#            6       0.78      0.82      0.80        22
#            7       0.84      0.96      0.90        28
#            8       0.97      0.85      0.90        33
#            9       0.85      0.92      0.88        25
#           10       0.86      0.93      0.89        27
#           11       0.83      0.95      0.88        20
#           12       0.67      0.67      0.67        24
#           13       0.87      0.87      0.87        23
#           14       0.74      0.93      0.83        28
#           15       0.75      0.93      0.83        29
#           16       0.54      0.90      0.68        21
#           17       0.94      0.89      0.91        18
#           18       0.81      0.50      0.62        26
#           19       0.71      0.36      0.48        14
#
#     accuracy                           0.77       500
#    macro avg       0.77      0.76      0.76       500
# weighted avg       0.78      0.77      0.76       500

# %%
# Random search Cross-Validation
parameters = {'nb__alpha': uniform(loc =0, scale=10)}
clf = RandomizedSearchCV(pipeline_ex, parameters, n_iter=7, cv=5)

clf.fit(Xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('tfidf',
#                                               TfidfVectorizer(stop_words='english')),
#                                              ('nb', MultinomialNB())]),
#                    n_iter=7,
#                    param_distributions={'nb__alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7e9add42deb0>})

# %%
# Result
ypred = clf.predict(Xtest)
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.43      0.53        21
#            1       0.72      0.62      0.67        21
#            2       0.60      0.69      0.64        26
#            3       0.73      0.71      0.72        34
#            4       0.78      0.85      0.82        34
#            5       0.90      0.69      0.78        26
#            6       1.00      0.73      0.84        22
#            7       0.72      1.00      0.84        28
#            8       0.90      0.82      0.86        33
#            9       0.92      0.88      0.90        25
#           10       0.84      1.00      0.92        27
#           11       0.76      0.95      0.84        20
#           12       0.61      0.58      0.60        24
#           13       0.82      0.78      0.80        23
#           14       0.88      0.82      0.85        28
#           15       0.54      0.90      0.68        29
#           16       0.50      0.95      0.66        21
#           17       0.94      0.83      0.88        18
#           18       0.88      0.27      0.41        26
#           19       0.00      0.00      0.00        14
#
#     accuracy                           0.75       500
#    macro avg       0.74      0.73      0.71       500
# weighted avg       0.75      0.75      0.73       500
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
